# %%
# importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# reading the provided csv file from desktop
df = pd.read_csv(r'C:\Users\zeez\Desktop\My Doc\Hamoye\task1.csv', encoding = "ANSI")

# %%
# visualizing data
df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
# info about data for datatype
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     60943 non-null  int64
#  1   Area          60943 non-null  object
#  2   Item Code     60943 non-null  int64
#  3   Item          60943 non-null  object
#  4   Element Code  60943 non-null  int64
#  5   Element       60943 non-null  object
#  6   Unit          60943 non-null  object
#  7   Y2014         59354 non-null  float64
#  8   Y2015         59395 non-null  float64
#  9   Y2016         59408 non-null  float64
#  10  Y2017         59437 non-null  float64
#  11  Y2018         59507 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 5.6+ MB

# %%
# counting missing values
df.isna().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
# further information
df.describe(include = 'all')
# Out:
#            Area Code   Area     Item Code                     Item  \
# count   60943.000000  60943  60943.000000                    60943
# unique           NaN     49           NaN                      119
# top              NaN  Kenya           NaN  Milk - Excluding Butter
# freq             NaN   1560           NaN                     1262
# mean      134.265576    NaN   2687.176706                      NaN
# std        72.605709    NaN    146.055739                      NaN
# min         4.000000    NaN   2501.000000                      NaN
# 25%        74.000000    NaN   2562.000000                      NaN
# 50%       136.000000    NaN   2630.000000                      NaN
# 75%       195.000000    NaN   2775.000000                      NaN
# max       276.000000    NaN   2961.000000                      NaN
#
#         Element Code                   Element         Unit          Y2014  \
# count   60943.000000                     60943        60943   59354.000000
# ...

# %%
# ANSWERING QUESTION 11 - 20

# %%
df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
# 11
# grouping by Item as item_grp
item_grp = df.groupby('Item')

# %%
# getting group for Animal fats
item_grp.get_group('Animal fats')[['Y2014', 'Y2017']].sum().to_frame()
# Out:
#                0
# Y2014  209460.54
# Y2017  269617.53

# %%
# 12
round(df['Y2015'].mean(), 3), round(df['Y2015'].std(), 3)
# Out:
# (135.236, 1603.404)

# %%
# 13
df['Y2016'].isna().sum(), round(df['Y2016'].isna().sum() / df['Y2016'].count() * 100, 2)
# Out:
# (1535, 2.58)

# %%
# 14
df[['Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018', 'Element Code']].corr().iloc[-1].to_frame()
# Out:
#               Element Code
# Y2014             0.024457
# Y2015             0.023889
# Y2016             0.023444
# Y2017             0.024254
# Y2018             0.024279
# Element Code      1.000000

# %%
# 15
df['Element'].value_counts()
# Out:
# Domestic supply quantity                  5295
# Import Quantity                           5139
# Protein supply quantity (g/capita/day)    5023
# Fat supply quantity (g/capita/day)        5023
# Food supply (kcal/capita/day)             5014
# Food                                      4941
# Food supply quantity (kg/capita/yr)       4905
# Residuals                                 4655
# Export Quantity                           4403
# Stock Variation                           4232
# Production                                3881
# Processing                                2010
# Losses                                    2009
# Other uses (non-food)                     1732
# Feed                                      1319
# Seed                                       762
# Tourist consumption                        555
# Total Population - Both sexes               45
# Name: Element, dtype: int64

# %%
# grouping by Element as element_grp
element_grp = df.groupby('Element')

# %%
# getting group for Import Quantity
element_grp.get_group('Import Quantity')[['Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018']].sum().to_frame()
# Out:
#                0
# Y2014  274144.48
# Y2015  267018.46
# Y2016  286582.78
# Y2017  294559.09
# Y2018  287997.09

# %%
element_grp.get_group('Import Quantity')[['Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018']].sum().max()
# Out:
# 294559.09

# %%
# 16
# grouping by element to get sum of production in year 2014
(df.groupby('Element')).get_group('Production')['Y2014'].sum()
# Out:
# 1931287.75

# %%
# 17 & 18
# selecting year 2018 and element.grouping by element. 
df[['Y2018', 'Element']].groupby('Element').sum()
# Out:
#                                              Y2018
# Element
# Domestic supply quantity                2161192.10
# Export Quantity                          181594.80
# Fat supply quantity (g/capita/day)        10258.69
# Feed                                     233489.68
# Food                                    1303841.28
# Food supply (kcal/capita/day)            455261.00
# Food supply quantity (kg/capita/yr)       49056.85
# Import Quantity                          287997.09
# Losses                                   163902.00
# Other uses (non-food)                     91300.97
# Processing                               308429.00
# Production                              2075072.89
# Protein supply quantity (g/capita/day)    11833.56
# Residuals                                 34864.00
# Seed                                      25263.14
# Stock Variation                           20577.91
# Total Population - Both sexes           1140605.00
# ...

# %%
df[['Y2018', 'Element']].groupby('Element').sum().rank(ascending = 0)
# Out:
#                                         Y2018
# Element
# Domestic supply quantity                  1.0
# Export Quantity                           9.0
# Fat supply quantity (g/capita/day)       17.0
# Feed                                      8.0
# Food                                      3.0
# Food supply (kcal/capita/day)             5.0
# Food supply quantity (kg/capita/yr)      12.0
# Import Quantity                           7.0
# Losses                                   10.0
# Other uses (non-food)                    11.0
# Processing                                6.0
# Production                                2.0
# Protein supply quantity (g/capita/day)   16.0
# Residuals                                13.0
# Seed                                     14.0
# Stock Variation                          15.0
# Total Population - Both sexes             4.0
# Tourist consumption                      18.0

# %%
df[['Y2018', 'Element']].groupby('Element').sum().rank()
# Out:
#                                         Y2018
# Element
# Domestic supply quantity                 18.0
# Export Quantity                          10.0
# Fat supply quantity (g/capita/day)        2.0
# Feed                                     11.0
# Food                                     16.0
# Food supply (kcal/capita/day)            14.0
# Food supply quantity (kg/capita/yr)       7.0
# Import Quantity                          12.0
# Losses                                    9.0
# Other uses (non-food)                     8.0
# Processing                               13.0
# Production                               17.0
# Protein supply quantity (g/capita/day)    3.0
# Residuals                                 6.0
# Seed                                      5.0
# Stock Variation                           4.0
# Total Population - Both sexes            15.0
# Tourist consumption                       1.0

# %%
# 19
# creating a group called alg
alg = df[['Y2018', 'Element', 'Area']].groupby('Area').get_group('Algeria')

# %%
# getting sum of Import Quantity
alg.groupby('Element').sum().loc['Import Quantity'].to_frame()
# Out:
#        Import Quantity
# Y2018         36238.29

# %%
# 20
# getting total number of unique countries
len(df['Area'].unique())
# Out:
# 49
